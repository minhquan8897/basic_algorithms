# %%
#計算する
2*(3+4)
# Out:
# 14

# %% [markdown]
# # 初めてのノートブック
#
# **コードを書てみましょう**

# %% [markdown]
# #出力してみましょう
# ...
#
# # First value: 1
# ...

# %%
'''
値を出力する
'''

print('first value' ,  1)
# Out:
# first value 1

# %% [markdown]
# **`sort`の関数を呼び出す**
#
# 1.以下のリストを作る
#
#
#
# ```
# Numbers =[4,3,2,1]
# ```
# 2.`sort()`　の関数を使って、リストをソートする。
#
# 3.printを使っ手、出力する`

# %%
Numbers= [4,3,2,1]
Numbers. sort()
print(Numbers)
# Out:
# [1, 2, 3, 4]
